# %%
import pandas as pd
import seaborn as sns

# %%
dat = pd.read_feather("data.feather")

# %%
dat.head()
# Out:
#   question  answer
# 0  FOURDAY     3.0
# 1  FOURDAY     3.0
# 2  FOURDAY     6.0
# 3  FOURDAY     1.0
# 4  FOURDAY     5.0

# %%
sns.barplot(data=dat, x='question', y='answer')

# %%
sns.catplot(data=dat, y='answer', col='question', kind='count')
